# %%
# !pip install ultralytics
# Out:
# ...
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.1 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063

# %%
from ultralytics import YOLO

model = YOLO('yolov8x-seg.pt')

results = model.train(data='./ch-SOHO.yaml', imgsz=1024, epochs=1000, batch=-1)
# Out:
# New https://pypi.org/project/ultralytics/8.1.25 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.23 🚀 Python-3.10.10 torch-2.2.1+cu121 CUDA:0 (NVIDIA TITAN RTX, 24210MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8x-seg.pt')

model.train(data='./ar.yaml', imgsz=256, epochs=300, batch=-1, save_period=50)
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/home/artipark/.config/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.
# ...
#   0%|          | 0.00/137M [00:00<?, ?B/s]
# New https://pypi.org/project/ultralytics/8.1.19 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.145 🚀 Python-3.7.16 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 4090, 24195MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# ...

# %%
from ultralytics import YOLO

model = YOLO('ch-soho-grayscale.pt')

# %%
a = model.predict('data/ch-test(SOHO)/images/20110102_1313_eit195_1024.png', 
              save=False, imgsz=1024, show_boxes=False)
# Out:
# image 1/1 /home/deeplearningtitan/Studenti/bakalarka-yolov8/data/ch-test(SOHO)/images/20110102_1313_eit195_1024.png: 1024x1024 4 coronal holes, 72.9ms
# Speed: 2.0ms preprocess, 72.9ms inference, 1.4ms postprocess per image at shape (1, 3, 1024, 1024)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

def show_prediction(yolo_model, img_path, imgsz=1024):
    result = yolo_model.predict(img_path, save=False, imgsz=imgsz, show_boxes=False)

    mask_tensors = result[0].masks.data

    dimention = result[0].masks.shape[1]
    prediction = np.full((dimention, dimention, 3), 0, dtype=np.uint8)

    for mask_tensor in mask_tensors:
        mask_array = mask_tensor.cpu().numpy().astype(np.uint8)
        prediction[mask_array == 1] = 255

    
    fig, axes = plt.subplots(1, 3, figsize=(12, 4), squeeze=False)
    axes[0, 0].set_axis_off()
    axes[0, 1].set_axis_off()
    axes[0, 2].set_axis_off()
    axes[0, 0].set_title("Image", fontsize=22)
    axes[0, 1].set_title("Mask", fontsize=22)
    axes[0, 2].set_title("Prediction", fontsize=22)
    img = np.array(Image.open(img_path).convert("L"))
    mask = np.array(Image.open(img_path.replace("images", "masks")))
    axes[0, 0].imshow(img, cmap="gray")
    axes[0, 1].imshow(mask)
    axes[0, 2].imshow(prediction)
    plt.show()

show_prediction(model, 'data/ch-test(SOHO)/images/20110102_1313_eit195_1024.png')
# Out:
# image 1/1 /home/deeplearningtitan/Studenti/bakalarka-yolov8/data/ch-test(SOHO)/images/20110102_1313_eit195_1024.png: 1024x1024 4 coronal holes, 72.8ms
# Speed: 2.1ms preprocess, 72.8ms inference, 1.5ms postprocess per image at shape (1, 3, 1024, 1024)
